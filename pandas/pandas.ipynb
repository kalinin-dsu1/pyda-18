# %% [markdown]
# ## Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

ratings = pd.read_csv('ml-latest-small/ratings.csv')
movies = pd.read_csv('ml-latest-small/movies.csv')

best_movie_id = ratings[ ratings.rating == 5.0 ]['movieId'].value_counts().index[0]
movies[ movies.movieId == best_movie_id ]['title'].values[0]
# Out:
# 'Shawshank Redemption, The (1994)'

# %% [markdown]
# ## Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
import pandas as pd

power = pd.read_csv('power.csv')
power[ 
    (power.country.isin(['Latvia', 'Lithuania', 'Estonia']))
    & (power.category.isin([4, 12, 21]))
    & (power.year >= 2005)
    & (power.year <= 2010)
    & (power.quantity > 0)
]['quantity'].sum()
# Out:
# 240580.0

# %% [markdown]
# ## Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
import pandas as pd

quotes = pd.read_html('https://fortrader.org/quotes')

quotes
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
#  0  EURRUB Курс евро к рублю сегодня  89.39       1.24          1.41        NaN
#  1       USDRUB Курс рубля к доллару  74.91       0.59          0.79        NaN,
#                                Название    Цена  Изменение  Изменение(%)  \
#  0       Нефть Brent Курс нефти сегодня   64.33       0.36          0.56
#  1          Нефть WTI Цены на нефть WTI   59.65      -1.22         -2.00
#  2  Природный газ Цена на природный газ    2.58       0.06          2.55
#  3                                 Кофе  130.10       1.10          0.85
#  4                             Кукуруза  550.00      -6.60         -1.19
#  5                                  Соя  396.60     -11.30         -2.77
#  6                               Хлопок   84.56      -0.12         -0.14
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
#                             Название   Цена  Изменение  Изменение(%)  Обновлено
#  0       Золото Цена золота на бирже  1 740      -6.00         -0.00        NaN
#  1  Серебро Цена на серебро на бирже  25.75      -0.12         -0.46        NaN
#  2         Палладий Цена на Палладий  2 607      -4.00         -0.00        NaN
#  3           Платина Цены на платину  1 187      -2.00         -0.00        NaN
#  4           Медь Цена меди на бирже   4.14       0.05          1.27        NaN,
#                                          Название      Цена  Изменение  \
#  0                                  ВТБ Акции ВТБ  0.038170    0.00032
#  1                         Газпром Акции газпрома    221.91   -3.49000
#  2                            Лукойл Акции Лукойл   6 119.0   41.00000
#  3                        Роснефть Акции Роснефти    562.95    2.65000
#  4                       Сбербанк Акции Сбербанка    288.43    2.96000
#  5           Сургутнефтегаз Акции Сургутнефтегаза    34.290    0.02500
#  6                      Норникель Акции Норникель    22 756   70.00000
#  7                       Аэрофлот Акции Аерофлота     69.22   -0.58000
#  8                    Северсталь Акции Северсталь  1 411.80  -10.80000
#  9                    Транснефть Акции Транснефть   146 950  500.00000
#  10             Ростелеком Курс акций ростелекома    107.51   -0.66000
#  11                      РУСАЛ Акции РУСАЛ (RUAL)    46.890    0.36500
#  12      Детский мир iDreamSky Technology Limited    137.62    2.30000
#  13             Петропавловск Акции Петропавловск     25.35   -0.75000
#  14                    Алроса Акции АЛРОСА (ALRS)   105.900    0.20000
#  15                    Магнит Акции Магнит (MGNT)   5 402.0  -26.50000
#  16                        НМЛК Акции НЛМК (NLMK)   218.300   -0.04000
#  17                  М.видео Акции М.видео (MVID)    717.90    0.30000
#  18    Газпром нефть Акции "Газпром нефть" (SIBN)    372.45    0.50000
#  19                        НМТП Акции НМТП (NMTP)    7.7650   -0.00500
#  20            Полиметалл Акции Полиметалл (POLY)  1 541.00   -3.60000
#  21        Полюс Золото Акции Полюс Золото (PLZL)  14 095.0 -273.00000
#  22                  НОВАТЭК Акции НОВАТЭК (NVTK)  1 435.60    7.80000
#  23                РусГидро Акции РусГидро (HYDR)    0.8112    0.00440
#  24                Татнефть Акции Татнефть (TATN)    600.70    2.70000
#  25        АФК Система Акции АФК "Система" (AFKS)    34.251   -0.09700
#  26                                 МТС Акции МТС    319.30    1.90000
#  27                Башнефть Акции Башнефть (BANE)   1 613.0  -32.00000
#  28                    Яндекс Акции Яндекс (YNDX)   4 885.8  -34.20000
#  29  X5 Retail Group Акции X5 Retail Group (FIVE)  2 476.00  -73.00000
#  30                  ФСК ЕЭС Акции ФСК ЕЭС (FEES)   0.21438    0.00030
#  31                      Мечел Акции Мечел (MTLR)     67.04   -1.47000
#  32                МосБиржа Акции МосБиржа (MOEX)    168.54    0.37000
#  33              Интер РАО Акции Интер РАО (IRAO)      5.07   -0.01000
#  34              Mail.ru Акции Mail.ru (MAIL, ДР)  1 794.80    2.80000
#  35                        Киви Акции Киви (QIWI)     805.0    0.00000
#  36                  Лента Акции Лента (LNTA, ДР)    255.90   -0.30000
#  37            Тинькофф Акции Тинькофф (TCSG, др)  4 397.20  100.00000
#  38                        Озон Акции Озон (Ozon)  4 220.00    6.50000
#
#      Изменение(%)  Обновлено
#  0       0.845443        NaN
#  1      -1.550000        NaN
#  2       0.700000        NaN
#  3       0.470000        NaN
#  4       1.040000        NaN
#  5       0.073000        NaN
#  6       0.000000        NaN
#  7      -0.830000        NaN
#  8      -0.760000        NaN
#  9       0.000000        NaN
#  10     -0.610000        NaN
#  11      0.785000        NaN
#  12      1.700000        NaN
#  13     -2.870000        NaN
#  14      0.189000        NaN
#  15     -0.500000        NaN
#  16     -0.018000        NaN
#  17      0.040000        NaN
#  18      0.130000        NaN
#  19     -0.064400        NaN
#  20     -0.230000        NaN
#  21     -1.900000        NaN
#  22      0.550000        NaN
#  23      0.545400        NaN
#  24      0.450000        NaN
#  25     -0.282000        NaN
#  26      0.600000        NaN
#  27     -1.900000        NaN
#  28     -0.700000        NaN
#  29     -2.860000        NaN
#  30      0.140130        NaN
#  31     -2.150000        NaN
#  32      0.220000        NaN
#  33     -0.120000        NaN
#  34      0.160000        NaN
#  35      0.000000        NaN
#  36     -0.120000        NaN
#  37      2.330000        NaN
#  38      0.150000        NaN  ,
#                                 Название      Цена  Изменение  Изменение(%)  \
#  0           Google Акции Google (GOOGL)  2 029.01       2.05          0.10
#  1                   IBM Акции IBM (IBM)    130.14       1.24          0.96
#  2     Microsoft Акции Майкрософт (MSFT)    236.08       5.73          2.49
#  3              Apple Акции Apple (AAPL)    123.35       3.36          2.80
#  4                  Yandex Акции яндекса     65.17      -0.38         -0.58
#  5                   Toyota Акции Тойоты    153.06      -5.52         -3.48
#  6      Volkswagen Курс акций Volkswagen    236.95      13.20          5.90
#  7            Amazon Акции Amazon (AMZN)  3 103.00      28.04          0.91
#  8           Boeing Акции Boeing Company    251.19      -4.63         -1.81
#  9              Intel Акции Intel (INTC)     65.65       1.89          2.96
#  10            Coca-Cola Акции Coca-Cola     50.78      -0.03         -0.06
#  11         Netflix Акции Netflix (NFLX)    521.75       9.57          1.87
#  12            Pfizer Акции Pfizer (PFE)     35.96       0.43          1.21
#  13                        AMD Акции AMD     80.26       1.20          1.52
#  14  Walt Disney Акции Walt Disney (DIS)    192.90       1.76          0.92
#  15           NVIDIA Акции NVIDIA (NVDA)    527.77      13.94          2.71
#  16           PayPal Акции PayPal (PYPL)    243.79       2.51          1.04
#  17         Facebook Акции Facebook (FB)    293.01       2.90          1.00
#  18             Tesla Акции Тесла (TSLA)    668.15      13.28          2.03
#  19            Twiter Цена акций твитера     65.16      -1.07         -1.62
#  20    Hasbro Цена на акции Hasbro, Inc.     93.45      -2.48         -2.59
#  21                               Сименс    135.92      -2.02         -1.46
#  22                                 Qiwi     10.73      -0.13         -1.20
#  23     Mastercard Акции Mastercard (МА)    358.40       1.89          0.53
#  24         Moderna Акции Модерна (MRNA)    145.40       1.66          1.15
#  25        Макдональдс Акции Макдональдс    224.72       2.28          1.02
#  26                                 MSCI    400.00     -10.36         -2.52
#  27                             FIXPRICE      9.66       0.00          0.00
#  28                 Zoom Акции Zoom (ZM)    327.50       1.24          0.38
#  29     HeadHunter Акции HeadHunter (HH)     34.67      -1.40         -3.88
#
#      Обновлено
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN
#  4         NaN
#  5         NaN
#  6         NaN
#  7         NaN
#  8         NaN
#  9         NaN
#  10        NaN
#  11        NaN
#  12        NaN
#  13        NaN
#  14        NaN
#  15        NaN
#  16        NaN
#  17        NaN
#  18        NaN
#  19        NaN
#  20        NaN
#  21        NaN
#  22        NaN
#  23        NaN
#  24        NaN
#  25        NaN
#  26        NaN
#  27        NaN
#  28        NaN
#  29        NaN  ,
#                                           Название       Цена Изменение  \
#  0         Индекс МосБиржи Индекс МосБиржи (IMOEX)    346 025      -350
#  1                    Индекс РТС Индекс РТС (RTSI)   1 467.62     -6.43
#  2                      Dow Jones Индекс Dow Jones  32 731.20   +103.20
#  3                          S&P 500 Индекс S&P 500      3 933       +36
#  4                    Nasdaq 100 Индекс Nasdaq 100  13 086.50   +219.50
#  5   Euro Stoxx 50 Индекс Euro Stoxx 50 (STOXX50E)    3 834.1      -4.7
#  6                            FTSE 100 Индекс FTSE   6 726.10    +17.39
#  7             Nikkei 225 Индекс Nikkei 225 (N225)     29 278       -57
#  8                Russell 2000 Индекс Russell 2000   2 147.42      0.00
#  9                              DAX30 Индекс DAX30   14 612.7     +17.6
#  10                           CAC 40 Индекс CAC 40    5 964.6     -37.4
#  11                         IBEX 35 Индекс IBEX 35    8 348.2    -153.4
#  12                         ASX 200 Индекс ASX 200    6 725.2      +3.2
#  13        Фьючерс РТС Курс фьючерса на индекс РТС    144 200    -1 750
#
#      Изменение(%)  Обновлено
#  0          -0.00        NaN
#  1          -0.44        NaN
#  2           0.32        NaN
#  3           1.00        NaN
#  4           1.71        NaN
#  5          -0.10        NaN
#  6           0.26        NaN
#  7          -0.00        NaN
#  8           0.00        NaN
#  9           0.10        NaN
#  10         -0.60        NaN
#  11         -1.80        NaN
#  12          0.00        NaN
#  13         -1.00        NaN  ,
#                                             Название       Цена  Изменение  \
#  0                         EUR/USD Евро / Доллар США    1.19358    0.00522
#  1                         GBP/USD Фунт / Доллар США    1.38649    0.00317
#  2                            USD/CHF Доллар / Франк    0.92312   -0.00690
#  3                         USD/JPY Доллар США / Иена  108.80500   -0.06600
#  4                             USD/CNH Доллар / Юань    6.50490   -0.00630
#  5             USD/CAD Доллар США / Канадский доллар    1.25205   -0.00034
#  6         AUD/USD Австралийский доллар / Доллар США    0.77470    0.00246
#  7                              EUR/CHF Евро / Франк    1.10188   -0.00332
#  8   AUD/CAD Австралийский доллар / Канадский доллар    0.96994    0.00283
#  9                      EUR/JPY Евро / Японская йена  129.87200    0.49200
#  10                              EUR/GBP Евро / Фунт    0.86070    0.00169
#  11                              GBP/JPY Фунт / Йена  150.85200    0.24900
#  12            NZDUSD New Zealand Dollar / US Dollar    0.71643    0.00130
#
#      Изменение(%)  Обновлено
#  0        0.43926        NaN
#  1        0.22916        NaN
#  2       -0.74192        NaN
#  3       -0.06100        NaN
#  4       -0.09680        NaN
#  5       -0.02715        NaN
#  6        0.31855        NaN
#  7       -0.30040        NaN
#  8        0.29262        NaN
#  9        0.38000        NaN
#  10       0.19674        NaN
#  11       0.16500        NaN
#  12       0.18179        NaN  ,
#                                               Название       Цена  Изменение  \
#  0                               Bitcoin Курс биткоина  55 519.90  -1 812.10
#  1          Litecoin Курс лайткоин к доллару (LTC/USD)     191.64      -3.93
#  2   BitcoinCash Курс Биткоин кеш к доллару США (BC...     521.53      -1.77
#  3                                           Dash Dash     214.88      -6.13
#  4                                       Ripple Ripple    0.56357   +0.04671
#  5                                   Ethereum Ethereum   1 730.94     -51.86
#  6                                         Zcash (ZEC)      144.5       -3.7
#  7                                           NEO (NEO)     41.573     -0.902
#  8                                           EOS (EOS)      4.229     +0.073
#  9                                          TRON (TRX)   0.061428  -0.001777
#  10                                             Monero     225.26      -6.65
#  11                                               IOTA     1.4685    +0.0597
#  12                       ETC/USD эфириум классик, ETC     12.024     +0.052
#
#      Изменение(%)  Обновлено
#  0      -3.160000        NaN
#  1      -2.010000        NaN
#  2      -0.340000        NaN
#  3      -2.770000        NaN
#  4       9.037260        NaN
#  5      -2.910000        NaN
#  6      -2.500000        NaN
#  7      -2.124000        NaN
#  8       1.749000        NaN
#  9      -2.811486        NaN
#  10     -2.870000        NaN
#  11      4.237600        NaN
#  12      0.434000        NaN  ]
